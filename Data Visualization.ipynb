# %%
cells=[40,46,54,60,70,76,80,82]
print(cells)
marks
# Out:
# [40, 46, 54, 60, 70, 76, 80, 82]
# [45, 50, 55, 60, 65, 70.75, 80]

# %%
import matplotlib.pyplot as plt
plt.plot (cells, marker='*', color='r', label= 'exam analysis')

# %%
marks=[45, 50, 55,60,65,70,75,80]
print(marks)
marks
# Out:
# [45, 50, 55, 60, 65, 70, 75, 80]
# [45, 50, 55, 60, 65, 70, 75, 80]

# %%
import matplotlib.pyplot as plt
plt.plot (marks, marker='*', color='r', label= 'exam analysis')

# %%
import matplotlib.pyplot as plt
plt.plot (cells, marker='*', color='r')
plt.plot(marks,marker='*',color='b')
plt.ylabel('marks')
plt.xlabel('students')
plt.title('exam  analysis')
plt.xtics()
# Out:
# Text(0.5, 1.0, 'exam  analysis')

# %%
import matplotlib.pyplot as plt
plt.plot (cells, marker='*', color='r')
plt.plot(marks,marker='*',color='b')
plt.ylabel('marks')
plt.xlabel('students')
plt.title('exam  analysis')
plt.xticks()
# Out:
# (array([-1.,  0.,  1.,  2.,  3.,  4.,  5.,  6.,  7.,  8.]),
#  [Text(-1.0, 0, '−1'),
#   Text(0.0, 0, '0'),
#   Text(1.0, 0, '1'),
#   Text(2.0, 0, '2'),
#   Text(3.0, 0, '3'),
#   Text(4.0, 0, '4'),
#   Text(5.0, 0, '5'),
#   Text(6.0, 0, '6'),
#   Text(7.0, 0, '7'),
#   Text(8.0, 0, '8')])

# %%
import pandas as pd

# Load the Excel file
file_path = r"C:\Users\user\Documents\exam.csv.xlsx"
data = pd.read_excel(file_path)

# Display the first few rows of the dataframe
print(data)
# Out:
#               Name  marks  cells
# 0  Claire Thompson     45     40
# 1   Jacob Reynolds     50     46
# 2   Olivia Stewart     55     54
# 3   Ethan Mitchell     60     60
# 4  Isabella Rogers     65     70
# 5    Daniel Parker     70     76
# 6   Sophia Bennett     75     80
# 7     Ryan Collins     80     82

# %%
import pandas as pd

# Load the Excel file
file_path = r"C:\Users\user\Documents\exam.csv.xlsx"
data = pd.read_excel(file_path)

# Display the first few rows of the dataframe
print(data)
plt.show
# Out:
#               Name  marks  cells
# 0  Claire Thompson     45     40
# 1   Jacob Reynolds     50     46
# 2   Olivia Stewart     55     54
# 3   Ethan Mitchell     60     60
# 4  Isabella Rogers     65     70
# 5    Daniel Parker     70     76
# 6   Sophia Bennett     75     80
# 7     Ryan Collins     80     82
# <function matplotlib.pyplot.show(close=None, block=None)>
